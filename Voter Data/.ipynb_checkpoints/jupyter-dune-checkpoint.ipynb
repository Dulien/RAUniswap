# %%
from duneanalytics import DuneAnalytics
import pandas

# initialize client
dune = DuneAnalytics('dulien', 'temp1234')

# try to login
dune.login()

# fetch token
dune.fetch_auth_token()

# %%
import json

pd.io.json._json.loads = lambda s, *a, **kw: json.loads(s)

# monkeypatch using faster simplejson module
import simplejson
pd.io.json._json.loads = lambda s, *a, **kw: simplejson.loads(s)

# normalising (unnesting) at the same time (for nested jsons)
pd.io.json._json.loads = lambda s, *a, **kw: pandas.json_normalize(simplejson.loads(s))

# %%
result_id = dune.query_result_id(query_id=868963)
data = dune.query_result(result_id)
print(data)
# Out:
# {'data': {'query_results': [{'id': 'c2ba635c-4562-4dc8-aee8-a37297534c09', 'job_id': 'fa1b248b-82b8-4a10-b929-699efce28b51', 'runtime': 0, 'generated_at': '2022-06-12T21:31:51.271389+00:00', 'columns': ['voter', 'proposalId', 'support', 'votes', 'reason', 'contract_address', 'evt_tx_hash', 'evt_index', 'evt_block_time', 'evt_block_number'], '__typename': 'query_results'}], 'query_errors': [], 'get_result_by_result_id': [{'data': {'contract_address': '\\x408ed6354d4973f66138c91495f2f2fcbd8724c3', 'evt_block_number': 13553145, 'evt_block_time': '2021-11-04T23:30:38+00:00', 'evt_index': 307, 'evt_tx_hash': '\\xd1963da94947c2cd4f10867207fb5b12b08b242f120d8aadbdb73e26109eece6', 'proposalId': 9, 'reason': '', 'support': 1, 'voter': '\\xd724107ae1047b50b543ad4d940dee18e99261f1', 'votes': 100000738338212320570}, '__typename': 'get_result_template'}, {'data': {'contract_address': '\\x408ed6354d4973f66138c91495f2f2fcbd8724c3', 'evt_block_number': 13553257, 'evt_block_time': '2021-11-05T00:00:27+00:00', 'evt_index': 377, 'evt_tx_hash': '\\x7f50b7474f5f003bdb6e6c0cd2310c94f70897fdeb8eacd84f8bb8487dc49670', 'proposalId': 9, 'reason': '', 'support': 1, 'voter': '\\x9b68c14e936104e9a7a24c712beecdc220002984', 'votes': 2500011568647808654464178}, '__typename': 'get_result_template'}, {'data': {'contract_address': '\\x408ed6354d4973f66138c91495f2f2fcbd8724c3', 'evt_block_number': 13554645, 'evt_block_time': '2021-11-05T05:08:38+00:00', 'evt_index': 343, 'evt_tx_hash': '\\x862a063d162ee5cd4896c7f05be25cdcf80dfd925b62db59d0aefc1b61c0b9d9', 'proposalId': 9, 'reason': '', 'support': 1, 'voter': '\\x458ceec48586a85fcfeb4a179706656ee321730e', 'votes': 4355769499936288851960712}, '__typename': 'get_result_template'}, {'data': {'contract_address': '\\x408ed6354d4973f66138c91495f2f2fcbd8724c3', 'evt_block_number': 13556434, 'evt_block_time': '2021-11-05T11:52:33+00:00', 'evt_index': 591, 'evt_tx_hash': '\\xfaf07fab6405c52eb78d53a2d53c6845679dda8cbbdc764535c62db5415a9329', 'proposalId': 9, 'reason': '', 'support': 1, 'voter': '\\xf4844a06d4f995c4c03195afcb5aa59dcbb5b4fc', 'votes': 254466199284232816910}, '__typename': 'get_result_template'}, {'data': {'contract_address': '\\x408ed6354d4973f66138c91495f2f2fcbd8724c3', 'evt_block_number': 13556443, 'evt_block_time': '2021-11-05T11:54:31+00:00', 'evt_index': 493, 'evt_tx_hash': '\\xfdb14f0cbeb41fe03b468e102c12b41c32051c22c6b78077d1ce10573044fcbd', 'proposalId': 9, 'reason': '', 'support': 1, 'voter': '\\xe87be8e831c019b1113f1ea5f8ffd9ba65828bf2', 'votes': 10542468119913401204}, '__typename': 'get_result_template'}, {'data': {'contract_address': '\\x408ed6354d4973f66138c91495f2f2fcbd8724c3', 'evt_block_number': 13559127, 'evt_block_time': '2021-11-05T21:54:25+00:00', 'evt_index': 39, 'evt_tx_hash': '\\x69ffb2a0a2cb5ece4a2215bf70b8c99b611be209ab92532565f91125a76c15cb', 'proposalId': 9, 'reason': '', 'support': 1, 'voter': '\\x47c125dee6898b6cb2379bcbafc823ff3f614770', 'votes': 4500000000000000000000000}, '__typename': 'get_result_template'}, {'data': {'contract_address': '\\x408ed6354d4973f66138c91495f2f2fcbd8724c3', 'evt_block_number': 13559132, 'evt_block_time': '2021-11-05T21:54:45+00:00', 'evt_index': 342, 'evt_tx_hash': '\\xc17357108afefaa6486fcc67837d567429ceeb6862a9de4ab85f21e230498526', 'proposalId': 9, 'reason': '', 'support': 1, 'voter': '\\xe25d5c876e24c52f0938967fb6e164bb70bb2362', 'votes': 323522936945918182}, '__typename': 'get_result_template'}, {'data': {'contract_address': '\\x408ed6354d4973f66138c91495f2f2fcbd8724c3', 'evt_block_number': 13560055, 'evt_block_time': '2021-11-06T01:21:33+00:00', 'evt_index': 276, 'evt_tx_hash': '\\xfae2a003749c388b6bf6d9171c599c28d199c6818ad91de6b99bda00f6e27161', 'proposalId': 9, 'reason': '', 'support': 1, 'voter': '\\x8d07d225a769b7af3a923481e1fdf49180e6a265', 'votes': 4001543755527125430772197}, '__typename': 'get_result_template'}, {'data': {'contract_address': '\\x408ed6354d4973f66138c91495f2f2fcbd8724c3', 'evt_block_number': 13560159, 'evt_block_time':  ...

# %%
dataframe = pandas.read_json("C:\Stuff\School\S2022\RA\Dune Analytics\V3-Votes.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_8424\549694138.py in <module>
# ----> 1 dataframe = pd.read_json("C:\Stuff\School\S2022\RA\Dune Analytics\V3-Votes.json")
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     612
#     613     with json_reader:
# --> 614         return json_reader.read()
#     615
#     616
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\json\_json.py in read(self)
#     746                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     747         else:
# --> 748             obj = self._get_object_parser(self.data)
#     749         self.close()
#     750         return obj
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     768         obj = None
#     769         if typ == "frame":
# --> 770             obj = FrameParser(json, **kwargs).parse()
#     771
#     772         if typ == "series" or obj is None:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     883
#     884         else:
# --> 885             self._parse_no_numpy()
#     886
#     887         if self.obj is None:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1138         if orient == "columns":
#    1139             self.obj = DataFrame(
# -> 1140                 loads(json, precise_float=self.precise_float), dtype=None
#    1141             )
#    1142         elif orient == "split":
#
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_8424\2326841793.py in <lambda>(s, *a, **kw)
#       8
#       9 # normalising (unnesting) at the same time (for nested jsons)
# ---> 10 pd.io.json._json.loads = lambda s, *a, **kw: pandas.json_normalize(simplejson.loads(s))
#
# NameError: name 'pandas' is not defined

# %%
display(dataframe)
# Out:
#                __typename                       data.contract_address  \
# 0     get_result_template  \x5e4be8bc9637f0eaa1a755019e06a68ce081d58f
# 1     get_result_template  \x5e4be8bc9637f0eaa1a755019e06a68ce081d58f
# 2     get_result_template  \x5e4be8bc9637f0eaa1a755019e06a68ce081d58f
# 3     get_result_template  \x5e4be8bc9637f0eaa1a755019e06a68ce081d58f
# 4     get_result_template  \x5e4be8bc9637f0eaa1a755019e06a68ce081d58f
# ...                   ...                                         ...
# 1485  get_result_template  \xc4e172459f1e7939d522503b81afaac1014ce6f6
# 1486  get_result_template  \xc4e172459f1e7939d522503b81afaac1014ce6f6
# 1487  get_result_template  \xc4e172459f1e7939d522503b81afaac1014ce6f6
# 1488  get_result_template  \xc4e172459f1e7939d522503b81afaac1014ce6f6
# 1489  get_result_template  \xc4e172459f1e7939d522503b81afaac1014ce6f6
#
#       data.evt_block_number       data.evt_block_time  data.evt_index  \
# 0                  11049095 2020-10-13 19:08:28+00:00             260
# 1                  11049121 2020-10-13 19:12:54+00:00              89
# 2                  11049139 2020-10-13 19:16:30+00:00             143
# 3                  11049409 2020-10-13 20:12:52+00:00             226
# 4                  11049558 2020-10-13 20:46:12+00:00             224
# ...                     ...                       ...             ...
# 1485               13076126 2021-08-22 16:16:32+00:00            1109
# 1486               13082390 2021-08-23 15:35:22+00:00             462
# 1487               13093230 2021-08-25 07:34:27+00:00             275
# 1488               13093372 2021-08-25 08:08:04+00:00             197
# 1489               13094770 2021-08-25 13:16:42+00:00             477
#
#                                        data.evt_tx_hash  data.proposalId  \
# 0     \xebd8ef4a5878c49cae6c10d8ce78b5fe8e5f20487d2e...                1
# 1     \x053a1e6a8cf761a7d018c6b10561abbf8929cba9c9ad...                1
# 2     \xeba1005e1f7d71821b3391d87fa709c14d06faf2dd42...                1
# 3     \x1712db96841e342db61a1b77db56cfba8a12f6745f8c...                1
# 4     \x7e54ea77db106541179c23e490c45631125dbebb6252...                1
# ...                                                 ...              ...
# 1485  \x13b5f2cec59e368879a5b7aaff60c29b111af519a678...                3
# 1486  \x6c931ac5ba1237790f1c67adc89020f2fb2b0bcb26d3...                3
# 1487  \x11580eb3feb67323092018a1dadd3ca32dc974b0de16...                3
# 1488  \xef22a37035c507be33528930d5a5d21d451887d67198...                3
# 1489  \xf91d186144a071e9a1b45dfb86399bdebfb88ad6d638...                3
#
#       data.support                                  data.voter    data.votes
# 0             True  \x3fd607eb83413e239109a6345271f74eab82ad57  5.602520e+20
# 1             True  \x680ebdfc65152d2fae6f7117240544bd35e62eb3  1.500781e+20
# 2             True  \xc6391ef319d26ba6c88146bf29c6283d63a70af0  4.611934e+20
# 3            False  \x6af96801c33ec00f2c99c8bdfec0d4e902a4b00d  5.698543e+20
# 4             True  \xae5c9dc28d008b95b1bb54941950da7ab859aa23  6.443218e+22
# ...            ...                                         ...           ...
# 1485          True  \x8c9d2bf1d9dd9bfc10c3bad8a602074ef0de219d  4.000000e+20
# 1486          True  \xa2bf1b0a7e079767b4701b5a1d9d5700eb42d1d1  1.025000e+25
# 1487          True  \x1e2bbc8bcd8c285c586522956ff1c6d8922ed051  1.000000e+17
# 1488          True  \x759de6b9806a5f695b8fe92f58a6771fb5db52c6  7.271788e+19
# 1489          True  \x4256cb53314b750e3a89295fe105b3145d78409b  1.000000e+18
#
# [1490 rows x 10 columns]

# %%
voterdf = dataframe.drop(columns=["data.contract_address","data.evt_block_number","data.evt_block_time",
                                 "data.evt_index","data.evt_tx_hash","data.proposalId","data.support","data.votes","__typename"])

# %%
display(voterdf)
# Out:
#                                       data.voter
# 0     \x3fd607eb83413e239109a6345271f74eab82ad57
# 1     \x680ebdfc65152d2fae6f7117240544bd35e62eb3
# 2     \xc6391ef319d26ba6c88146bf29c6283d63a70af0
# 3     \x6af96801c33ec00f2c99c8bdfec0d4e902a4b00d
# 4     \xae5c9dc28d008b95b1bb54941950da7ab859aa23
# ...                                          ...
# 1485  \x8c9d2bf1d9dd9bfc10c3bad8a602074ef0de219d
# 1486  \xa2bf1b0a7e079767b4701b5a1d9d5700eb42d1d1
# 1487  \x1e2bbc8bcd8c285c586522956ff1c6d8922ed051
# 1488  \x759de6b9806a5f695b8fe92f58a6771fb5db52c6
# 1489  \x4256cb53314b750e3a89295fe105b3145d78409b
#
# [1490 rows x 1 columns]

# %%
voterdf.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                                       data.voter
# 0     \x3fd607eb83413e239109a6345271f74eab82ad57
# 1     \x680ebdfc65152d2fae6f7117240544bd35e62eb3
# 2     \xc6391ef319d26ba6c88146bf29c6283d63a70af0
# 3     \x6af96801c33ec00f2c99c8bdfec0d4e902a4b00d
# 4     \xae5c9dc28d008b95b1bb54941950da7ab859aa23
# ...                                          ...
# 1485  \x8c9d2bf1d9dd9bfc10c3bad8a602074ef0de219d
# 1486  \xa2bf1b0a7e079767b4701b5a1d9d5700eb42d1d1
# 1487  \x1e2bbc8bcd8c285c586522956ff1c6d8922ed051
# 1488  \x759de6b9806a5f695b8fe92f58a6771fb5db52c6
# 1489  \x4256cb53314b750e3a89295fe105b3145d78409b
#
# [1490 rows x 1 columns]>

# %%
display(voterdf)
# Out:
#                                       data.voter
# 0     \x3fd607eb83413e239109a6345271f74eab82ad57
# 1     \x680ebdfc65152d2fae6f7117240544bd35e62eb3
# 2     \xc6391ef319d26ba6c88146bf29c6283d63a70af0
# 3     \x6af96801c33ec00f2c99c8bdfec0d4e902a4b00d
# 4     \xae5c9dc28d008b95b1bb54941950da7ab859aa23
# ...                                          ...
