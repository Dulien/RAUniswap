# %%
import pandas as pd
import json
import csv
import time

with open('26K.csv', 'r') as file:
    reader = csv.reader(file)
    for data in reader:
        try:
            pdObj = pd.read_json("C:/Stuff/School/S2022/RA/RAUniswap/TC Data/ERC721 Transactions/JSON/data_"+data[0]+".json")
            csvData = pdObj.to_csv("data_"+data[0]+".csv")
            
        except:
            print(data[0]+" crashed")
# Out:
# ï»¿0x199712b27fbc8d17021c140c98148127b2cd83f3 crashed
# 0x2d46994b23fef6aec62cda7edd8c5ef03087be65 crashed
# 0xd4e9520a28c1e9b14bbcb75448d52a3064918613 crashed
# 0xbdbe7d3988e4454faba53643f684ddbaa9b8c302 crashed
# 0xc04f44994170536a73ce1acb8c6c68dcab198a06 crashed
# 0xc6e3aaf46d5c6bfea5e99ce580a9ed2460d31a60 crashed
# 0xad0eb7cae585d5a30ec3b9f7b70581552c482a77 crashed
# 0x862a432fe4a6a45d3447034dd711d3d323744590 crashed
# 0xe11a8d8b95a73ff21c72d36a117702951da64295 crashed
# 0x864870a0b1b90c4f7a922e4c191087e31f39cbfc crashed
# 0xf936c9b9825c627a2d69640432bbf3a9ba191500 crashed
# 0x28420fe46fcb7949d24c595c9d4ce0819d1b8ff6 crashed
# 0x3ae05a6a29e7058690348a94c9de6752c9dbaad4 crashed
# 0x13a8f694aed6437e70ba6f91e24897bac7c627dd crashed
# 0x8f492f2df0546dceacfefb8f22fb9d87b6a48b81 crashed
# 0xc645a246917f0c5f06d4b7fca2cc607c366c9739 crashed
# 0x1c636ea5356c3524d67fb2505a2f4713902382dc crashed
# 0x4be635364ffdbf618c561ae952d008bdf6afacf6 crashed
# ...

# %%
import pandas as pd

pdObj = pd.read_json("C:/Stuff/School/S2022/RA/RAUniswap/TC Data/ERC20 Transactions/JSON/data_data_0xffdd2cc5bd971e31347aa80f96327015bc011376.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_28596\3723497487.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 pdObj = pd.read_json("C:/Stuff/School/S2022/RA/RAUniswap/TC Data/ERC20 Transactions/JSON/data_data_0xffdd2cc5bd971e31347aa80f96327015bc011376.json")
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# ...

# %%
display(pdObj)
# Out:
#    blockNumber           timeStamp  \
# 0     10772705 2020-09-01 02:53:52
# 1     10774246 2020-09-01 08:39:21
# 2     10774246 2020-09-01 08:39:21
# 3     10890692 2020-09-19 05:12:12
#
#                                                 hash  nonce  \
# 0  0x74950ef69242e324042a78a4df17d5f6c626175aad1f...   3173
# 1  0x95263b36bf4de29b87e77b6c47012e2e9a8eeb553331...      2
# 2  0x95263b36bf4de29b87e77b6c47012e2e9a8eeb553331...      2
# 3  0xe22c255f2c78ca82b34e273f5c1e6e10d3d0fd13a009...      2
#
#                                            blockHash  \
# 0  0x9797efdca641e34d443b31794a25bd4dd6242ed8f0b3...
# 1  0x98e277cc37f6fed9f2f89eb962b958e87fc18899bfa2...
# 2  0x98e277cc37f6fed9f2f89eb962b958e87fc18899bfa2...
# 3  0xf17070503e3bf4d404c92b3ac15de64435e1ec87ed60...
#
#                                          from  \
# 0  0xdb6fdc30ab61c7cca742d4c13d1b035f3f82019a
# 1  0xfff7a828f5f3b465c4f857fa1757a8f80ba3c18c
# 2  0x7d829fcc84f9dca5a3e6d9fb73545bacf350146a
# ...
